# %% [markdown]
# <a href="https://colab.research.google.com/github/Tylerwitt27/Skyline-Math-200/blob/main/Python_research_question_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research Question # __ : Include question here: Is there an association between how much someone weighs and how often someone has trouble sleeping.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# ![Screenshot 2023-05-01 12.32.24 PM.png](data:image/png;base64,...)

# %% [markdown]
# Codebook 1

# %%
#Manage data for variable 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6504 entries, 0 to 6503
# Columns: 978 entries, AID to trouble_sleep
# dtypes: float64(1), int64(2), object(975)
# memory usage: 48.5+ MB

# %%
df['H4GH6'].dtype
# Out:
# dtype('O')

# %%
df['current_weight'] = df['H4GH6']
df['current_weight'].dtype
# Out:
# dtype('O')

# %%
df['current_weight'] = pd.to_numeric( df['current_weight'] , errors='coerce' )
df['current_weight'].dtype
# Out:
# dtype('float64')

# %%
df['current_weight'].value_counts()
# Out:
# 180.0    184
# 160.0    182
# 150.0    160
# 200.0    154
# 170.0    150
#         ...
# 239.0      1
# 318.0      1
# 266.0      1
# 321.0      1
# 306.0      1
# Name: current_weight, Length: 254, dtype: int64

# %%
rp.summary_cat(df['current_weight'])
# Out:
#            Variable  Outcome  Count  Percent
# 0    current_weight    180.0    184     3.60
# 1                      160.0    182     3.56
# 2                      150.0    160     3.13
# 3                      200.0    154     3.01
# 4                      170.0    150     2.93
# ..              ...      ...    ...      ...
# 249                    387.0      1     0.02
# 250                    355.0      1     0.02
# 251                    284.0      1     0.02
# 252                    457.0      1     0.02
# 253                    306.0      1     0.02
#
# [254 rows x 4 columns]

# %%
df['current_weight'] = df['current_weight'].loc[ df['current_weight'] < 617]
df['current_weight'].value_counts()
# Out:
# 180.0    184
# 160.0    182
# 150.0    160
# 200.0    154
# 170.0    150
#         ...
# 239.0      1
# 318.0      1
# 266.0      1
# 321.0      1
# 306.0      1
# Name: current_weight, Length: 252, dtype: int64

# %%
import seaborn as sns

# %%
df['current_weight'].describe()
# Out:
# count    5035.000000
# mean      184.050050
# std        49.337308
# min        18.000000
# 25%       150.000000
# 50%       178.000000
# 75%       211.000000
# max       525.000000
# Name: current_weight, dtype: float64

# %%
#Graphs and tables or statistics

# %%
sns.histplot( x = 'current_weight' , data= df, bins = 5)
# Out:
# <Axes: xlabel='current_weight', ylabel='Count'>

# %%
sns.histplot(x = 'current_weight', data =df, stat='percent', bins = 15, color = 'maroon', kde=True)
# Out:
# <Axes: xlabel='current_weight', ylabel='Percent'>

# %%
sns.boxplot( x = 'current_weight' , data= df)
# Out:
# <Axes: xlabel='current_weight'>

# %% [markdown]
# Codebook 2:

# %% [markdown]
# ![Screenshot 2023-05-01 12.53.53 PM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1

# %%
pip install researchPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import researchpy as rp

# %%
df['trouble_asleep'] = df['H4SP5']
df['trouble_asleep'].value_counts()
# Out:
# 0    2400
#      1390
# 1     950
# 2     911
# 4     411
# 3     395
# 5      46
# 8       1
# Name: trouble_asleep, dtype: int64

# %%
df['trouble_sleep']=df['H4SP5']
df['trouble_sleep']=df['trouble_sleep'].loc[df['trouble_sleep'] !=' ']
df['trouble_sleep']=df['trouble_sleep'].loc[df['trouble_sleep'] !='5']
df['trouble_sleep']=df['trouble_sleep'].loc[df['trouble_sleep'] !='6']
df['trouble_sleep']=df['trouble_sleep'].loc[df['trouble_sleep'] !='8']

# %%
df['trouble_sleep'].replace(['0','1','2','3','4'],['never in the past four weeks','less than once a week','1 or 2 times a week','3 or 4 times a week','5 or more times a week'],inplace=True)

# %%
import seaborn as sns

# %%
#Graphs and tables or statistics

# %%
rp.summary_cat(df['trouble_sleep'])
# Out:
#         Variable                       Outcome  Count  Percent
# 0  trouble_sleep  never in the past four weeks   2400    47.37
# 1                        less than once a week    950    18.75
# 2                          1 or 2 times a week    911    17.98
# 3                       5 or more times a week    411     8.11
# 4                          3 or 4 times a week    395     7.80

# %%
plt.title("Compared to your weight how often do you have trouble falling asleep")
df['trouble_sleep'].value_counts().plot(kind ='pie', autopct='%1.1f%%', colors=['olivedrab', 'rosybrown', 'gray', 'saddlebrown', 'red'])
# Out:
# <Axes: title={'center': 'Compared to your weight how often do you have trouble falling asleep'}, ylabel='trouble_sleep'>

# %%
plt.title("Compared to your weight how often do you have trouble falling asleep")
df['trouble_sleep'].value_counts(normalize = True).plot(kind ='bar', color = 'green', width = 0.2)
# Out:
# <Axes: title={'center': 'Compared to your weight how often do you have trouble falling asleep'}>
